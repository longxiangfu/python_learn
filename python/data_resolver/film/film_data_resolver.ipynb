# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import seaborn as sns
plt.style.use('ggplot')
import json

# %%
# 读取csv文件，返回DataFrame对象
movie = pd.read_csv('tmdb_5000_movies.csv')
credit = pd.read_csv('tmdb_5000_credits.csv')
print(type(movie))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
# 通过电影DataFrame对象，获取电影前3行数据
movie.head(3)
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615
# 2  A cryptic message from Bond’s past sends him o...  107.376788
#
#                                 production_companies  \
# 0  [{"name": "Ingenious Film Partners", "id": 289...
# 1  [{"name": "Walt Disney Pictures", "id": 2}, {"...
# 2  [{"name": "Columbia Pictures", "id": 5}, {"nam...
#
#                                 production_countries release_date     revenue  \
# 0  [{"iso_3166_1": "US", "name": "United States o...   2009-12-10  2787965087
# 1  [{"iso_3166_1": "US", "name": "United States o...   2007-05-19   961000000
# 2  [{"iso_3166_1": "GB", "name": "United Kingdom"...   2015-10-26   880674609
#
#    runtime                                   spoken_languages    status  \
# 0    162.0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 1    169.0           [{"iso_639_1": "en", "name": "English"}]  Released
# 2    148.0  [{"iso_639_1": "fr", "name": "Fran\u00e7ais"},...  Released
#
#                                           tagline  \
# 0                     Enter the World of Pandora.
# 1  At the end of the world, the adventure begins.
# 2                           A Plan No One Escapes
#
#                                       title  vote_average  vote_count
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
# 2                                   Spectre           6.3        4466

# %%
# 获取电影DataFrame对象的信息
movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                4803 non-null   int64
#  1   genres                4803 non-null   object
#  2   homepage              1712 non-null   object
#  3   id                    4803 non-null   int64
#  4   keywords              4803 non-null   object
#  5   original_language     4803 non-null   object
#  6   original_title        4803 non-null   object
#  7   overview              4800 non-null   object
#  8   popularity            4803 non-null   float64
#  9   production_companies  4803 non-null   object
#  10  production_countries  4803 non-null   object
#  11  release_date          4802 non-null   object
#  12  revenue               4803 non-null   int64
#  13  runtime               4801 non-null   float64
#  14  spoken_languages      4803 non-null   object
#  15  status                4803 non-null   object
#  16  tagline               3959 non-null   object
#  17  title                 4803 non-null   object
#  18  vote_average          4803 non-null   float64
#  19  vote_count            4803 non-null   int64
# dtypes: float64(3), int64(4), object(13)
# memory usage: 750.6+ KB

# %%
# 通过评分DataFrame对象，获取评分前3行数据
credit.head(3)
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...

# %%
# 获取评分DataFrame对象信息
credit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   movie_id  4803 non-null   int64
#  1   title     4803 non-null   object
#  2   cast      4803 non-null   object
#  3   crew      4803 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 150.2+ KB

# %% [markdown]
# # 数据清洗

# %%
print(type(movie['genres']))
# Out:
# <class 'pandas.core.series.Series'>

# %%
# 清洗电影DataFrame对象的genres列数据
# 将movie中所有的genres列数据都应用json.loads函数,将列数据转换成了python对象:字典列表
movie['genres'] = movie['genres'].apply(json.loads)
movie['genres'].head(3)
# Out:
# 0    [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 1    [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2    [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# Name: genres, dtype: object

# %%
print(type(movie['genres']))
# Out:
# <class 'pandas.core.series.Series'>

# %%
# 将电影DataFrame对象中每一行的genres列数据映射成列表，该列表中的元素为原列数据中name内容
for index, genres in zip(movie.index, movie['genres']):
    l = []
    for _ in genres:
        l.append(_['name'])
    movie.loc[index, 'genres'] = str(l)

# %%
movie.head(4)
# Out:
#       budget                                             genres  \
# 0  237000000  ['Action', 'Adventure', 'Fantasy', 'Science Fi...
# 1  300000000                 ['Adventure', 'Fantasy', 'Action']
# 2  245000000                   ['Action', 'Adventure', 'Crime']
# 3  250000000           ['Action', 'Crime', 'Drama', 'Thriller']
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
# 3  [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615
# 2  A cryptic message from Bond’s past sends him o...  107.376788
# 3  Following the death of District Attorney Harve...  112.312950
#
#                                 production_companies  \
# 0  [{"name": "Ingenious Film Partners", "id": 289...
# 1  [{"name": "Walt Disney Pictures", "id": 2}, {"...
# 2  [{"name": "Columbia Pictures", "id": 5}, {"nam...
# 3  [{"name": "Legendary Pictures", "id": 923}, {"...
#
#                                 production_countries release_date     revenue  \
# 0  [{"iso_3166_1": "US", "name": "United States o...   2009-12-10  2787965087
# 1  [{"iso_3166_1": "US", "name": "United States o...   2007-05-19   961000000
# 2  [{"iso_3166_1": "GB", "name": "United Kingdom"...   2015-10-26   880674609
# 3  [{"iso_3166_1": "US", "name": "United States o...   2012-07-16  1084939099
#
#    runtime                                   spoken_languages    status  \
# 0    162.0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 1    169.0           [{"iso_639_1": "en", "name": "English"}]  Released
# 2    148.0  [{"iso_639_1": "fr", "name": "Fran\u00e7ais"},...  Released
# 3    165.0           [{"iso_639_1": "en", "name": "English"}]  Released
#
#                                           tagline  \
# 0                     Enter the World of Pandora.
# 1  At the end of the world, the adventure begins.
# 2                           A Plan No One Escapes
# 3                                 The Legend Ends
#
#                                       title  vote_average  vote_count
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
# 2                                   Spectre           6.3        4466
# 3                     The Dark Knight Rises           7.6        9106

# %%
def json2list(name):
    movie[name] = movie[name].apply(json.loads)
    for index, genres in zip(movie.index, movie[name]):
        l = []
        for _ in genres:
            l.append(_['name'])
        movie.loc[index, name] = str(l)

# %%
# 清洗keywords production_companies spoken_languages，和对genres列的操作一样
# j2l = ['keywords', 'production_companies', 'spoken_languages']
# for _ in j2l:
#     json2list(_)
json2list('keywords')
json2list('production_companies')
json2list('spoken_languages')

# %%
movie.head(4)
# Out:
#       budget                                             genres  \
# 0  237000000  ['Action', 'Adventure', 'Fantasy', 'Science Fi...
# 1  300000000                 ['Adventure', 'Fantasy', 'Action']
# 2  245000000                   ['Action', 'Adventure', 'Crime']
# 3  250000000           ['Action', 'Crime', 'Drama', 'Thriller']
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
#
#                                             keywords original_language  \
# 0  ['culture clash', 'future', 'space war', 'spac...                en
# 1  ['ocean', 'drug abuse', 'exotic island', 'east...                en
# 2  ['spy', 'based on novel', 'secret agent', 'seq...                en
# 3  ['dc comics', 'crime fighter', 'terrorist', 's...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615
# 2  A cryptic message from Bond’s past sends him o...  107.376788
# 3  Following the death of District Attorney Harve...  112.312950
#
#                                 production_companies  \
# 0  ['Ingenious Film Partners', 'Twentieth Century...
# 1  ['Walt Disney Pictures', 'Jerry Bruckheimer Fi...
# 2             ['Columbia Pictures', 'Danjaq', 'B24']
# 3  ['Legendary Pictures', 'Warner Bros.', 'DC Ent...
#
#                                 production_countries release_date     revenue  \
# 0  [{"iso_3166_1": "US", "name": "United States o...   2009-12-10  2787965087
# 1  [{"iso_3166_1": "US", "name": "United States o...   2007-05-19   961000000
# 2  [{"iso_3166_1": "GB", "name": "United Kingdom"...   2015-10-26   880674609
# 3  [{"iso_3166_1": "US", "name": "United States o...   2012-07-16  1084939099
#
#    runtime                                   spoken_languages    status  \
# 0    162.0                             ['English', 'Español']  Released
# 1    169.0                                        ['English']  Released
# 2    148.0  ['Français', 'English', 'Español', 'Italiano',...  Released
# 3    165.0                                        ['English']  Released
#
#                                           tagline  \
# 0                     Enter the World of Pandora.
# 1  At the end of the world, the adventure begins.
# 2                           A Plan No One Escapes
# 3                                 The Legend Ends
#
#                                       title  vote_average  vote_count
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
# 2                                   Spectre           6.3        4466
# 3                     The Dark Knight Rises           7.6        9106

# %%
credit.head(3)
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...

# %%
# 清洗cast crew
def json2list_credit(name):
    credit[name] = credit[name].apply(json.loads)
    for index, data in zip(credit.index, credit[name]):
        l = []
        for _ in data:
            l.append(_['name'])
        credit.loc[index, name] = str(l)

# %%
json2list_credit('cast')
json2list_credit('crew')

# %%
credit.head(3)
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
#
#                                                 cast  \
# 0  ['Sam Worthington', 'Zoe Saldana', 'Sigourney ...
# 1  ['Johnny Depp', 'Orlando Bloom', 'Keira Knight...
# 2  ['Daniel Craig', 'Christoph Waltz', 'Léa Seydo...
#
#                                                 crew
# 0  ['Stephen E. Rivkin', 'Rick Carter', 'Christop...
# 1  ['Dariusz Wolski', 'Gore Verbinski', 'Jerry Br...
# 2  ['Thomas Newman', 'Sam Mendes', 'Anna Pinnock'...

# %%
# 合并电影DataFrame对象和评分DataFrame对象。相当于mysql的左连接查询
all_df = pd.merge(movie, credit, left_on='id', right_on='movie_id', how='left')

# %%
all_df.head(3)
# Out:
#       budget                                             genres  \
# 0  237000000  ['Action', 'Adventure', 'Fantasy', 'Science Fi...
# 1  300000000                 ['Adventure', 'Fantasy', 'Action']
# 2  245000000                   ['Action', 'Adventure', 'Crime']
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
#
#                                             keywords original_language  \
# 0  ['culture clash', 'future', 'space war', 'spac...                en
# 1  ['ocean', 'drug abuse', 'exotic island', 'east...                en
# 2  ['spy', 'based on novel', 'secret agent', 'seq...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615
# 2  A cryptic message from Bond’s past sends him o...  107.376788
#
#                                 production_companies  ...  \
# 0  ['Ingenious Film Partners', 'Twentieth Century...  ...
# 1  ['Walt Disney Pictures', 'Jerry Bruckheimer Fi...  ...
# 2             ['Columbia Pictures', 'Danjaq', 'B24']  ...
#
#                                     spoken_languages    status  \
# 0                             ['English', 'Español']  Released
# 1                                        ['English']  Released
# 2  ['Français', 'English', 'Español', 'Italiano',...  Released
#
#                                           tagline  \
# 0                     Enter the World of Pandora.
# 1  At the end of the world, the adventure begins.
# 2                           A Plan No One Escapes
#
#                                     title_x vote_average vote_count movie_id  \
# 0                                    Avatar          7.2      11800    19995
# 1  Pirates of the Caribbean: At World's End          6.9       4500      285
# 2                                   Spectre          6.3       4466   206647
#
#                                     title_y  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
#
#                                                 cast  \
# 0  ['Sam Worthington', 'Zoe Saldana', 'Sigourney ...
# 1  ['Johnny Depp', 'Orlando Bloom', 'Keira Knight...
# 2  ['Daniel Craig', 'Christoph Waltz', 'Léa Seydo...
#
#                                                 crew
# 0  ['Stephen E. Rivkin', 'Rick Carter', 'Christop...
# 1  ['Dariusz Wolski', 'Gore Verbinski', 'Jerry Br...
# 2  ['Thomas Newman', 'Sam Mendes', 'Anna Pinnock'...
#
# [3 rows x 24 columns]

# %%
# 查看数据量。行数列数
all_df.shape
# Out:
# (4803, 24)

# %%
# 修改列名
all_df.rename(columns={'title_x':'title'}, inplace=True)  # inplace直接修改原DataFrame,不返回新的DataFrame
all_df.drop('title_y', axis=1, inplace=True)  # 删除列title_y   axis=1作用于列   axis=0作用于行

# %%
all_df.head(3)
# Out:
#       budget                                             genres  \
# 0  237000000  ['Action', 'Adventure', 'Fantasy', 'Science Fi...
# 1  300000000                 ['Adventure', 'Fantasy', 'Action']
# 2  245000000                   ['Action', 'Adventure', 'Crime']
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
#
#                                             keywords original_language  \
# 0  ['culture clash', 'future', 'space war', 'spac...                en
# 1  ['ocean', 'drug abuse', 'exotic island', 'east...                en
# 2  ['spy', 'based on novel', 'secret agent', 'seq...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615
# 2  A cryptic message from Bond’s past sends him o...  107.376788
#
#                                 production_companies  ... runtime  \
# 0  ['Ingenious Film Partners', 'Twentieth Century...  ...   162.0
# 1  ['Walt Disney Pictures', 'Jerry Bruckheimer Fi...  ...   169.0
# 2             ['Columbia Pictures', 'Danjaq', 'B24']  ...   148.0
#
#                                     spoken_languages    status  \
# 0                             ['English', 'Español']  Released
# 1                                        ['English']  Released
# 2  ['Français', 'English', 'Español', 'Italiano',...  Released
#
#                                           tagline  \
# 0                     Enter the World of Pandora.
# 1  At the end of the world, the adventure begins.
# 2                           A Plan No One Escapes
#
#                                       title vote_average vote_count movie_id  \
# 0                                    Avatar          7.2      11800    19995
# 1  Pirates of the Caribbean: At World's End          6.9       4500      285
# 2                                   Spectre          6.3       4466   206647
#
#                                                 cast  \
# 0  ['Sam Worthington', 'Zoe Saldana', 'Sigourney ...
# 1  ['Johnny Depp', 'Orlando Bloom', 'Keira Knight...
# 2  ['Daniel Craig', 'Christoph Waltz', 'Léa Seydo...
#
#                                                 crew
# 0  ['Stephen E. Rivkin', 'Rick Carter', 'Christop...
# 1  ['Dariusz Wolski', 'Gore Verbinski', 'Jerry Br...
# 2  ['Thomas Newman', 'Sam Mendes', 'Anna Pinnock'...
#
# [3 rows x 23 columns]

# %%
# all_df.isnull() : 单元数据如果为NaN，则返回True,否则返回False。还是原来的结构
# all_df.isnull().head(3)

# 按列统计NaN值
# all_df.isnull().sum()

# 转成DF
pd.DataFrame(all_df.isnull().sum(axis=0))
# Out:
#                          0
# budget                   0
# genres                   0
# homepage              3091
# id                       0
# keywords                 0
# original_language        0
# original_title           0
# overview                 3
# popularity               0
# production_companies     0
# production_countries     0
# release_date             1
# revenue                  0
# runtime                  2
# spoken_languages         0
# status                   0
# tagline                844
# title                    0
# vote_average             0
# vote_count               0
# movie_id                 0
# cast                     0
# crew                     0

# %%
# 查看数据缺失
nas = pd.DataFrame(all_df.isnull().sum(axis=0))
nas.loc[nas[0]>0].sort_values(by=0, ascending=False)
# Out:
#                  0
# homepage      3091
# tagline        844
# overview         3
# runtime          2
# release_date     1

# %%
# 返回列'release_date'为NaN的行
all_df.loc[all_df['release_date'].isnull()]
# Out:
#       budget genres homepage      id keywords original_language  \
# 4553       0     []      NaN  380097       []                en
#
#                   original_title  \
# 4553  America Is Still the Place
#
#                                                overview  popularity  \
# 4553  1971 post civil rights San Francisco seemed li...         0.0
#
#      production_companies  ... runtime spoken_languages    status  tagline  \
# 4553                   []  ...     0.0               []  Released      NaN
#
#                            title vote_average vote_count movie_id  cast  crew
# 4553  America Is Still the Place          0.0          0   380097    []    []
#
# [1 rows x 23 columns]

# %%
# 将release_date缺失部分进行填充
all_df['release_date'] = all_df['release_date'].fillna('2014-06-01')

# %%
all_df.loc[all_df['release_date'].isnull()]
# Out:
# Empty DataFrame
# Columns: [budget, genres, homepage, id, keywords, original_language, original_title, overview, popularity, production_companies, production_countries, release_date, revenue, runtime, spoken_languages, status, tagline, title, vote_average, vote_count, movie_id, cast, crew]
# Index: []
#
# [0 rows x 23 columns]

# %%
nas = pd.DataFrame(all_df.isnull().sum())
nas[nas[0]>0].sort_values(by=[0], ascending=False)
# Out:
#              0
# homepage  3091
# tagline    844
# overview     3

# %%
all_df.loc[all_df['runtime'].isnull()]
# Out:
#         budget           genres homepage      id  \
# 2656  15000000        ['Drama']      NaN  370980
# 4140         2  ['Documentary']      NaN  459488
#
#                                                keywords original_language  \
# 2656                              ['pope', 'biography']                it
# 4140  ['music', 'actors', 'legendary perfomer', 'cla...                en
#
#                                   original_title overview  popularity  \
# 2656  Chiamatemi Francesco - Il Papa della gente      NaN    0.738646
# 4140                 To Be Frank, Sinatra at 100      NaN    0.050625
#
#            production_companies  ... runtime spoken_languages    status  \
# 2656            ['Taodue Film']  ...     NaN      ['Español']  Released
# 4140  ['Eyeline Entertainment']  ...     NaN               []  Released
#
#       tagline                                       title vote_average  \
# 2656      NaN  Chiamatemi Francesco - Il Papa della gente          7.3
# 4140      NaN                 To Be Frank, Sinatra at 100          0.0
#
#      vote_count movie_id                                               cast  \
# 2656         12   370980  ['Rodrigo de la Serna', 'Sergio Hernández', 'À...
# 4140          0   459488                                ['Tony Oppedisano']
#
#                                                    crew
# 2656  ['Daniele Luchetti', 'Daniele Luchetti', 'Kevi...
# 4140                              ['Simon Napier-Bell']
#
# [2 rows x 23 columns]

# %%
# 对runtime列数据缺失部分进行填充
# all_df['runtime'].mean()   计算列'runtime'的平均值
all_df['runtime'] = all_df['runtime'].fillna(all_df['runtime'].mean())

# %%
all_df.loc[all_df['runtime'].isnull()]
# Out:
# Empty DataFrame
# Columns: [budget, genres, homepage, id, keywords, original_language, original_title, overview, popularity, production_companies, production_countries, release_date, revenue, runtime, spoken_languages, status, tagline, title, vote_average, vote_count, movie_id, cast, crew]
# Index: []
#
# [0 rows x 23 columns]

# %%
type(pd.to_datetime(all_df['release_date'], format='%Y-%m-%d'))
# Out:
# pandas.core.series.Series

# %%
# 处理日期。加了列：年、月
all_df['release_year'] = pd.to_datetime(all_df['release_date'], format='%Y-%m-%d').dt.year
all_df['release_month'] = pd.to_datetime(all_df['release_date'], format='%Y-%m-%d').dt.month

# %%
all_df.head(5)
# Out:
#       budget                                             genres  \
# 0  237000000  ['Action', 'Adventure', 'Fantasy', 'Science Fi...
# 1  300000000                 ['Adventure', 'Fantasy', 'Action']
# 2  245000000                   ['Action', 'Adventure', 'Crime']
# 3  250000000           ['Action', 'Crime', 'Drama', 'Thriller']
# 4  260000000         ['Action', 'Adventure', 'Science Fiction']
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  ['culture clash', 'future', 'space war', 'spac...                en
# 1  ['ocean', 'drug abuse', 'exotic island', 'east...                en
# 2  ['spy', 'based on novel', 'secret agent', 'seq...                en
# 3  ['dc comics', 'crime fighter', 'terrorist', 's...                en
# 4  ['based on novel', 'mars', 'medallion', 'space...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615
# 2  A cryptic message from Bond’s past sends him o...  107.376788
# 3  Following the death of District Attorney Harve...  112.312950
# 4  John Carter is a war-weary, former military ca...   43.926995
#
#                                 production_companies  ...    status  \
# 0  ['Ingenious Film Partners', 'Twentieth Century...  ...  Released
# 1  ['Walt Disney Pictures', 'Jerry Bruckheimer Fi...  ...  Released
# 2             ['Columbia Pictures', 'Danjaq', 'B24']  ...  Released
# 3  ['Legendary Pictures', 'Warner Bros.', 'DC Ent...  ...  Released
# 4                           ['Walt Disney Pictures']  ...  Released
#
#                                           tagline  \
# 0                     Enter the World of Pandora.
# 1  At the end of the world, the adventure begins.
# 2                           A Plan No One Escapes
# 3                                 The Legend Ends
# 4            Lost in our world, found in another.
#
#                                       title  vote_average vote_count movie_id  \
# 0                                    Avatar           7.2      11800    19995
# 1  Pirates of the Caribbean: At World's End           6.9       4500      285
# 2                                   Spectre           6.3       4466   206647
# 3                     The Dark Knight Rises           7.6       9106    49026
# 4                               John Carter           6.1       2124    49529
#
#                                                 cast  \
# 0  ['Sam Worthington', 'Zoe Saldana', 'Sigourney ...
# 1  ['Johnny Depp', 'Orlando Bloom', 'Keira Knight...
# 2  ['Daniel Craig', 'Christoph Waltz', 'Léa Seydo...
# 3  ['Christian Bale', 'Michael Caine', 'Gary Oldm...
# 4  ['Taylor Kitsch', 'Lynn Collins', 'Samantha Mo...
#
#                                                 crew  release_year  \
# 0  ['Stephen E. Rivkin', 'Rick Carter', 'Christop...          2009
# 1  ['Dariusz Wolski', 'Gore Verbinski', 'Jerry Br...          2007
# 2  ['Thomas Newman', 'Sam Mendes', 'Anna Pinnock'...          2015
# 3  ['Hans Zimmer', 'Charles Roven', 'Christopher ...          2012
# 4  ['Andrew Stanton', 'Andrew Stanton', 'John Las...          2012
#
#    release_month
# 0             12
# 1              5
# 2             10
# 3              7
# 4              3
#
# [5 rows x 25 columns]

# %%
all_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 25 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                4803 non-null   int64
#  1   genres                4803 non-null   object
#  2   homepage              1712 non-null   object
#  3   id                    4803 non-null   int64
#  4   keywords              4803 non-null   object
#  5   original_language     4803 non-null   object
#  6   original_title        4803 non-null   object
#  7   overview              4800 non-null   object
#  8   popularity            4803 non-null   float64
#  9   production_companies  4803 non-null   object
#  10  production_countries  4803 non-null   object
#  11  release_date          4803 non-null   object
#  12  revenue               4803 non-null   int64
#  13  runtime               4803 non-null   float64
#  14  spoken_languages      4803 non-null   object
#  15  status                4803 non-null   object
#  16  tagline               3959 non-null   object
#  17  title                 4803 non-null   object
#  18  vote_average          4803 non-null   float64
#  19  vote_count            4803 non-null   int64
#  20  movie_id              4803 non-null   int64
#  21  cast                  4803 non-null   object
#  22  crew                  4803 non-null   object
#  23  release_year          4803 non-null   int32
#  24  release_month         4803 non-null   int32
# dtypes: float64(3), int32(2), int64(5), object(15)
# memory usage: 900.7+ KB

# %% [raw]
# # 1.数据量最多的前10种电影类型

# %%
all_df.head(3)
# Out:
#       budget                                             genres  \
# 0  237000000  ['Action', 'Adventure', 'Fantasy', 'Science Fi...
# 1  300000000                 ['Adventure', 'Fantasy', 'Action']
# 2  245000000                   ['Action', 'Adventure', 'Crime']
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
#
#                                             keywords original_language  \
# 0  ['culture clash', 'future', 'space war', 'spac...                en
# 1  ['ocean', 'drug abuse', 'exotic island', 'east...                en
# 2  ['spy', 'based on novel', 'secret agent', 'seq...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615
# 2  A cryptic message from Bond’s past sends him o...  107.376788
#
#                                 production_companies  ...    status  \
# 0  ['Ingenious Film Partners', 'Twentieth Century...  ...  Released
# 1  ['Walt Disney Pictures', 'Jerry Bruckheimer Fi...  ...  Released
# 2             ['Columbia Pictures', 'Danjaq', 'B24']  ...  Released
#
#                                           tagline  \
# 0                     Enter the World of Pandora.
# 1  At the end of the world, the adventure begins.
# 2                           A Plan No One Escapes
#
#                                       title  vote_average vote_count movie_id  \
# 0                                    Avatar           7.2      11800    19995
# 1  Pirates of the Caribbean: At World's End           6.9       4500      285
# 2                                   Spectre           6.3       4466   206647
#
#                                                 cast  \
# 0  ['Sam Worthington', 'Zoe Saldana', 'Sigourney ...
# 1  ['Johnny Depp', 'Orlando Bloom', 'Keira Knight...
# 2  ['Daniel Craig', 'Christoph Waltz', 'Léa Seydo...
#
#                                                 crew  release_year  \
# 0  ['Stephen E. Rivkin', 'Rick Carter', 'Christop...          2009
# 1  ['Dariusz Wolski', 'Gore Verbinski', 'Jerry Br...          2007
# 2  ['Thomas Newman', 'Sam Mendes', 'Anna Pinnock'...          2015
#
#    release_month
# 0             12
# 1              5
# 2             10
#
# [3 rows x 25 columns]

# %%
all_data = all_df
# 去掉[]，将' '替换成'',将"'"替换成""
all_df['genres'] = all_df['genres'].str.strip('[]').str.replace(' ', '').str.replace("'", "")

# %%
all_df.head(3)
# Out:
#       budget                                   genres  \
# 0  237000000  Action,Adventure,Fantasy,ScienceFiction
# 1  300000000                 Adventure,Fantasy,Action
# 2  245000000                   Action,Adventure,Crime
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
#
#                                             keywords original_language  \
# 0  ['culture clash', 'future', 'space war', 'spac...                en
# 1  ['ocean', 'drug abuse', 'exotic island', 'east...                en
# 2  ['spy', 'based on novel', 'secret agent', 'seq...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615
# 2  A cryptic message from Bond’s past sends him o...  107.376788
#
#                                 production_companies  ...    status  \
# 0  ['Ingenious Film Partners', 'Twentieth Century...  ...  Released
# 1  ['Walt Disney Pictures', 'Jerry Bruckheimer Fi...  ...  Released
# 2             ['Columbia Pictures', 'Danjaq', 'B24']  ...  Released
#
#                                           tagline  \
# 0                     Enter the World of Pandora.
# 1  At the end of the world, the adventure begins.
# 2                           A Plan No One Escapes
#
#                                       title  vote_average vote_count movie_id  \
# 0                                    Avatar           7.2      11800    19995
# 1  Pirates of the Caribbean: At World's End           6.9       4500      285
# 2                                   Spectre           6.3       4466   206647
#
#                                                 cast  \
# 0  ['Sam Worthington', 'Zoe Saldana', 'Sigourney ...
# 1  ['Johnny Depp', 'Orlando Bloom', 'Keira Knight...
# 2  ['Daniel Craig', 'Christoph Waltz', 'Léa Seydo...
#
#                                                 crew  release_year  \
# 0  ['Stephen E. Rivkin', 'Rick Carter', 'Christop...          2009
# 1  ['Dariusz Wolski', 'Gore Verbinski', 'Jerry Br...          2007
# 2  ['Thomas Newman', 'Sam Mendes', 'Anna Pinnock'...          2015
#
#    release_month
# 0             12
# 1              5
# 2             10
#
# [3 rows x 25 columns]

# %%
all_df['genres'] = all_df['genres'].str.split(',')  # 按逗号切分，转换为list

# %%
all_df.head(3)
# Out:
#       budget                                        genres  \
# 0  237000000  [Action, Adventure, Fantasy, ScienceFiction]
# 1  300000000                  [Adventure, Fantasy, Action]
# 2  245000000                    [Action, Adventure, Crime]
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
#
#                                             keywords original_language  \
# 0  ['culture clash', 'future', 'space war', 'spac...                en
# 1  ['ocean', 'drug abuse', 'exotic island', 'east...                en
# 2  ['spy', 'based on novel', 'secret agent', 'seq...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615
# 2  A cryptic message from Bond’s past sends him o...  107.376788
#
#                                 production_companies  ...    status  \
# 0  ['Ingenious Film Partners', 'Twentieth Century...  ...  Released
# 1  ['Walt Disney Pictures', 'Jerry Bruckheimer Fi...  ...  Released
# 2             ['Columbia Pictures', 'Danjaq', 'B24']  ...  Released
#
#                                           tagline  \
# 0                     Enter the World of Pandora.
# 1  At the end of the world, the adventure begins.
# 2                           A Plan No One Escapes
#
#                                       title  vote_average vote_count movie_id  \
# 0                                    Avatar           7.2      11800    19995
# 1  Pirates of the Caribbean: At World's End           6.9       4500      285
# 2                                   Spectre           6.3       4466   206647
#
#                                                 cast  \
# 0  ['Sam Worthington', 'Zoe Saldana', 'Sigourney ...
# 1  ['Johnny Depp', 'Orlando Bloom', 'Keira Knight...
# 2  ['Daniel Craig', 'Christoph Waltz', 'Léa Seydo...
#
#                                                 crew  release_year  \
# 0  ['Stephen E. Rivkin', 'Rick Carter', 'Christop...          2009
# 1  ['Dariusz Wolski', 'Gore Verbinski', 'Jerry Br...          2007
# 2  ['Thomas Newman', 'Sam Mendes', 'Anna Pinnock'...          2015
#
#    release_month
# 0             12
# 1              5
# 2             10
#
# [3 rows x 25 columns]

# %%
genres_l = []
for i in all_df['genres']:
    genres_l.extend(i)
genres_l[:10]
# Out:
# ['Action',
#  'Adventure',
#  'Fantasy',
#  'ScienceFiction',
#  'Adventure',
#  'Fantasy',
#  'Action',
#  'Action',
#  'Adventure',
#  'Crime']

# %% [markdown]
# # 前10数量最多的电影类型

# %%
# 分组统计count
pd.Series(genres_l).value_counts()
# Out:
# Drama             2297
# Comedy            1722
# Thriller          1274
# Action            1154
# Romance            894
# Adventure          790
# Crime              696
# ScienceFiction     535
# Horror             519
# Family             513
# Fantasy            424
# Mystery            348
# Animation          234
# History            197
# Music              185
# War                144
# Documentary        110
# Western             82
# Foreign             34
#                     28
# TVMovie              8
# Name: count, dtype: int64

# %%
# 取前10个
gen_list = pd.Series(genres_l).value_counts()[:10]
gen_df = pd.DataFrame(gen_list)
# gen_df.rename(columns={0:"Total"}, inplace=True)

# %% [markdown]
# gen_df.head()

# %%
plt.subplots(figsize=(10, 8))  #设置画布大小
sns.barplot(y=gen_df.index, x='count', data=gen_df, palette='GnBu_d', hue=gen_df.index, legend=False)  #利用seaborn绘制柱状图   palette调色板
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.xlabel('Total', fontsize=12)
plt.ylabel('Genres',fontsize=12)
plt.title('Top q0 genres', fontsize=12)
plt.show()
